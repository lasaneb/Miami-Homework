# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path
import numpy as np

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

# %%
# Alternatively, use the provided csv file:
file_path = Path("Resources/crypto_data.csv")
crypto_df = pd.read_csv(file_path)

crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df.drop(columns=['Unnamed: 0'], )
crypto_df.head()
# Out:
#     CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 1    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 2    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 3  SixEleven   SHA-256       True       PoW              NaN          611000
# 4        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]
crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [1144 rows x 6 columns]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A']

crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 1         365Coin          X11       True   PoW/PoS              NaN
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 3       SixEleven      SHA-256       True       PoW              NaN
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
#
# [1144 rows x 6 columns]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns=['IsTrading'])
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 1         365Coin          X11   PoW/PoS              NaN      2300000000
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 3       SixEleven      SHA-256       PoW              NaN          611000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# 1243   Super Zero       Ethash       PoW              NaN      1000000000
# 1244          UOS      SHA-256      DPoI              NaN      1000000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] != 0]
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Drop rows where there are 'N/A' text values
for column in crypto_df:
    crypto_df = crypto_df.loc[crypto_df[column] != 'N/A']

crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df

coins_name = crypto_df[['CoinName']]

coins_name
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=['CoinName'])
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Create dummy variables for text features
x = pd.get_dummies(crypto_df)

x
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 0        4.199995e+01                                 0              0
# 2        1.055185e+09                                 0              0
# 5        2.927942e+10                                 0              0
# 7        1.792718e+07                                 0              0
# 8        1.076842e+08                                 0              0
# ...               ...                               ...            ...
# 1238     2.000000e+09                                 0              0
# 1242     1.493105e+07                                 0              0
# 1245     9.802226e+08                                 0              0
# 1246     7.296538e+06                                 0              0
# 1247     1.283270e+05                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0                     0                   0                0
# 2                     0                   0                0
# 5                     0                   0                0
# 7                     0                   0                0
# 8                     0                   0                0
# ...                 ...                 ...              ...
# 1238                  0                   0                0
# 1242                  0                   0                0
# 1245                  0                   0                0
# 1246                  0                   0                0
# 1247                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  \
# 0                     0                  0              0
# 2                     0                  0              0
# 5                     0                  0              0
# 7                     0                  0              0
# 8                     0                  0              0
# ...                 ...                ...            ...
# 1238                  0                  0              0
# 1242                  0                  0              0
# 1245                  0                  0              0
# 1246                  0                  0              0
# 1247                  0                  0              0
#
#       Algorithm_Cloverhash  ...  TotalCoinSupply_91388946  \
# 0                        0  ...                         0
# 2                        0  ...                         0
# 5                        0  ...                         0
# 7                        0  ...                         0
# 8                        0  ...                         0
# ...                    ...  ...                       ...
# 1238                     0  ...                         0
# 1242                     0  ...                         0
# 1245                     0  ...                         0
# 1246                     0  ...                         0
# 1247                     0  ...                         0
#
#       TotalCoinSupply_92000000000  TotalCoinSupply_9354000  \
# 0                               0                        0
# 2                               0                        0
# 5                               0                        0
# 7                               0                        0
# 8                               0                        0
# ...                           ...                      ...
# 1238                            0                        0
# 1242                            0                        0
# 1245                            0                        0
# 1246                            0                        0
# 1247                            0                        0
#
#       TotalCoinSupply_9507271  TotalCoinSupply_9736000  \
# 0                           0                        0
# 2                           0                        0
# 5                           0                        0
# 7                           0                        0
# 8                           0                        0
# ...                       ...                      ...
# 1238                        0                        0
# 1242                        0                        0
# 1245                        0                        0
# 1246                        0                        0
# 1247                        0                        0
#
#       TotalCoinSupply_98000000  TotalCoinSupply_98100000000  \
# 0                            0                            0
# 2                            0                            0
# 5                            0                            0
# 7                            0                            0
# 8                            0                            0
# ...                        ...                          ...
# 1238                         0                            0
# 1242                         0                            0
# 1245                         0                            0
# 1246                         0                            0
# 1247                         0                            0
#
#       TotalCoinSupply_990000000000  TotalCoinSupply_999481516  \
# 0                                0                          0
# 2                                0                          0
# 5                                0                          0
# 7                                0                          0
# 8                                0                          0
# ...                            ...                        ...
# 1238                             0                          0
# 1242                             0                          0
# 1245                             0                          0
# 1246                             0                          0
# 1247                             0                          0
#
#       TotalCoinSupply_9999999
# 0                           0
# 2                           0
# 5                           0
# 7                           0
# 8                           0
# ...                       ...
# 1238                        0
# 1242                        0
# 1245                        0
# 1246                        0
# 1247                        0
#
# [533 rows x 379 columns]

# %%
# Standardize data
scaler = StandardScaler()

crypto_scaled = scaler.fit_transform(x)
crypto_scaled
# Out:
# array([[-0.11674788, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.09358885, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [ 0.52587231, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        ...,
#        [-0.09523411, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11658774, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ],
#        [-0.11674507, -0.0433555 , -0.0433555 , ..., -0.0433555 ,
#         -0.0433555 , -0.0433555 ]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
crypto_pca = pca.fit_transform(crypto_scaled)

pcs_df = pd.DataFrame(data=crypto_pca, columns=["PC_1", "PC_2", "PC_3"], index=crypto_df.index)

pcs_df.head()
# Out:
#        PC_1      PC_2      PC_3
# 0 -0.275468 -0.125700 -0.315833
# 2 -0.253976 -0.129142 -0.310983
# 5  0.235683 -0.191585 -0.338613
# 7 -0.212539 -0.067850  0.064830
# 8 -0.119525 -0.103639  0.076944

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=3, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = crypto_df.join(pcs_df)
clustered_df['CoinName'] = coins_name['CoinName']
clustered_df['Class'] = predictions
clustered_df.head()
# Out:
#   Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC_1      PC_2  \
# 0    Scrypt   PoW/PoS     4.199995e+01              42 -0.275468 -0.125700
# 2    Scrypt   PoW/PoS     1.055185e+09       532000000 -0.253976 -0.129142
# 5       X13   PoW/PoS     2.927942e+10    314159265359  0.235683 -0.191585
# 7   SHA-256       PoW     1.792718e+07        21000000 -0.212539 -0.067850
# 8    Ethash       PoW     1.076842e+08               0 -0.119525 -0.103639
#
#        PC_3   CoinName  Class
# 0 -0.315833    42 Coin      0
# 2 -0.310983    404Coin      0
# 5 -0.338613  EliteCoin      0
# 7  0.064830    Bitcoin      0
# 8  0.076944   Ethereum      0

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
plt.yticks(np.arange(min, max, step))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-99246ebdc076> in <module>
#       1 # Scale data to create the scatter plot
# ----> 2 plt.yticks(np.arange(min, max, step))
#
# NameError: name 'step' is not defined

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
clustered_.hvplot(kind='scatter', x='TotalCoinsMined', y='TotalCoinSupply')"
# Out:
#   File "<ipython-input-55-ee9d2a73ce4c>", line 2
#     clustered_.hvplot(kind='scatter', x='TotalCoinsMined', y='TotalCoinSupply')"
#                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

# %%
# Print the total number of tradable cryptocurrencies
