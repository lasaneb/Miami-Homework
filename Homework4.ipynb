# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
# assign path & read for whale returns

csv_path = Path("/Users/xbook/Desktop/Bootcamp/FinTech/mia-virt-fin-pt-08-2021-u-c/Homework/04-Pandas/Instructions/Starter_Code/Resources/whale_returns.csv")
whaledata = pd.read_csv(csv_path)
whaledata.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
whaledata.dtypes
# Out:
# Date                            object
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
# convert the dates to a DateTimeIndex

whaledata['Date'] = pd.to_datetime(whaledata.Date)

#df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# Null identification 

whaledata.isnull()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# ...

# %%
#count nulls

whaledata.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls

whaledata.dropna(inplace=True)
whaledata
# Out:
#            Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1    2015-03-03                  -0.001266           -0.004981
# 2    2015-03-04                   0.002230            0.003241
# 3    2015-03-05                   0.004016            0.004076
# 4    2015-03-06                  -0.007905           -0.003574
# 5    2015-03-09                   0.000582            0.004225
# ...         ...                        ...                 ...
# 1055 2019-04-25                  -0.000285           -0.001291
# 1056 2019-04-26                   0.008149            0.009162
# 1057 2019-04-29                   0.001254            0.002719
# 1058 2019-04-30                  -0.001295           -0.002211
# 1059 2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# ...

# %%
# check null count

whaledata.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# assign path & read for algorithmic returns

csv_path = Path('/Users/xbook/Desktop/Bootcamp/FinTech/mia-virt-fin-pt-08-2021-u-c/Homework/04-Pandas/Instructions/Starter_Code/Resources/algo_returns.csv')
alg_day_ret = pd.read_csv(csv_path)
alg_day_ret.head()
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
# convert the dates to a DateTimeIndex

alg_day_ret['Date'] = pd.to_datetime(alg_day_ret.Date)

#df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# null id

alg_day_ret.isnull()
# Out:
#        Date  Algo 1  Algo 2
# 0     False   False    True
# 1     False   False    True
# 2     False   False    True
# 3     False   False    True
# 4     False   False    True
# ...     ...     ...     ...
# 1236  False   False   False
# 1237  False   False   False
# 1238  False   False   False
# 1239  False   False   False
# 1240  False   False   False
#
# [1241 rows x 3 columns]

# %%
# count nulls

alg_day_ret.isnull().sum ()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
alg_day_ret.dtypes
# Out:
# Date      datetime64[ns]
# Algo 1           float64
# Algo 2           float64
# dtype: object

# %%
# drop nulls

alg_day_ret.dropna(inplace=True)
alg_day_ret
# Out:
#            Date    Algo 1    Algo 2
# 6    2014-06-05  0.004062  0.013285
# 7    2014-06-06  0.001857  0.008284
# 8    2014-06-09 -0.005012  0.005668
# 9    2014-06-10  0.004406 -0.000735
# 10   2014-06-11  0.004760 -0.003761
# ...         ...       ...       ...
# 1236 2019-04-25  0.000682 -0.007247
# 1237 2019-04-26  0.002981  0.005256
# 1238 2019-04-29  0.005208  0.002829
# 1239 2019-04-30 -0.002944 -0.001570
# 1240 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 3 columns]

# %%
# check null count
alg_day_ret.isnull().sum ()
# Out:
# Date      0
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# assign path & read for algorithmic returns

csv_path = Path('/Users/xbook/Desktop/Bootcamp/FinTech/mia-virt-fin-pt-08-2021-u-c/Homework/04-Pandas/Instructions/Starter_Code/Resources/sp500_history.csv')
sp500 = pd.read_csv(csv_path)
sp500.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# convert the dates to a DateTimeIndex

sp500['Date'] = pd.to_datetime(sp500.Date)

#df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# data type check

sp500.dtypes
# Out:
# Date     datetime64[ns]
# Close            object
# dtype: object

# %%
#remove $ and convert Close colum to Float
#df['Close'] = df['Close'].str.replace('$','').astype(np.float64)
#df['Close'] = df['Close'].convert_objects(convert_numeric=True)

#sp500['Close'] = sp500['Close'].astype(int)
pd.DataFrame.pct_change
sp500.head
# Out:
# <bound method NDFrame.head of            Date     Close
# 0    2019-04-23  $2933.68
# 1    2019-04-22  $2907.97
# 2    2019-04-18  $2905.03
# 3    2019-04-17  $2900.45
# 4    2019-04-16  $2907.06
# ...         ...       ...
# 1644 2012-10-05  $1460.93
# 1645 2012-10-04  $1461.40
# 1646 2012-10-03  $1450.99
# 1647 2012-10-02  $1445.75
# 1648 2012-10-01  $1444.49
#
# [1649 rows x 2 columns]>

# %%
daily_returns = sp500.pct_change()
#daily_returns.head()

#daily_returns= 
#sp500.head()
sp500.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/FinTech/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~/opt/anaconda3/envs/FinTech/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/envs/FinTech/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
#drop Nulls

# %%
#rename "close" column

colums = ['Date', 'Close']
sp500 = sp500.rename(columns={'Close':'S&P EOD'})
#sp500

# %%
column_appended_data = pd.concat([whaledata, alg_day_ret, sp500], axis="rows", join="outer")
column_appended_data.head()
# Out:
#         Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1 2015-03-03                  -0.001266           -0.004981
# 2 2015-03-04                   0.002230            0.003241
# 3 2015-03-05                   0.004016            0.004076
# 4 2015-03-06                  -0.007905           -0.003574
# 5 2015-03-09                   0.000582            0.004225
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  Algo 2 S&P EOD
# 1                    -0.000496               -0.006569     NaN     NaN     NaN
# 2                    -0.002534                0.004213     NaN     NaN     NaN
# 3                     0.002355                0.006726     NaN     NaN     NaN
# 4                    -0.008481               -0.013098     NaN     NaN     NaN
# 5                     0.005843               -0.001652     NaN     NaN     NaN
